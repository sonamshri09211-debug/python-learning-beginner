# %%
#variables

a=20
b=50
c=a+b;

print("addition:",a+b)
print("subtraction:",a-b)
print("multiply:",a*b)
print("division:",a/b)
print("floor division:",a//b)
# Out:
# addition: 70
# subtraction: -30
# multiply: 1000
# division: 0.4
# floor division: 0
